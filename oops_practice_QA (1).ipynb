# %%
# Date 12 March

# %%
# Class : Company,attributes = name,sal,dept.....
# Sal() print salary
# func() named = bonus==> salary 5% add,

class Company:
    def __init__(self,name,sal,dept):
        self.name = name
        self.sal = sal
        self.dept = dept
        print("Good morning everyone!\nA little extra happiness today because it’s **Salary Day!\nHope everyone has a productive and cheerful day ahead.")
        print()
        
    def print_salary(self):
        print("The Salary of",self.name,"who is from",self.dept,"Department, is :",self.sal)

    def func(self):
        print("The Salary with 5% Bonus is :",self.sal + self.sal * 0.05)
        
employee1 = Company("Anisha",25000,"Management")
employee1.print_salary()
employee1.func()

print()

employee2 = Company("Megha",67000,"Finance")
employee2.print_salary()
employee2.func()
# Out:
# Good morning everyone!
# A little extra happiness today because it’s **Salary Day!
# Hope everyone has a productive and cheerful day ahead.
#
# The Salary of Anisha who is from Management Department, is : 25000
# The Salary with 5% Bonus is : 26250.0
#
# Good morning everyone!
# A little extra happiness today because it’s **Salary Day!
# Hope everyone has a productive and cheerful day ahead.
#
# The Salary of Megha who is from Finance Department, is : 67000
# The Salary with 5% Bonus is : 70350.0

# %%
#1. Write a class Person that has a method greet() which prints "Hello, welcome!". Create an object of the class and call the method.

class Person:
    def greet(self):
        print('"Hello,Welcome!"')
a1 = Person()
a1.greet()
# Out:
# "Hello,Welcome!"

# %%
#2. Write a class Student with a method show_name(self, name) that prints the student's name.

class Student:
    def show_name(self,name):
        self.name = name
        print("The Student's name is :",self.name)
        
Name = Student()
Name.show_name("Neha")
# Out:
# The Student's name is : Neha

# %%
#3. Write a class Car that takes brand and model as parameters using the init method and prints them using another method display().
class Car:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
    
    def display(self):
        print("The Brand of Car is",self.brand,"and the Model of Car is",self.model)
Car1 = Car("'TATA'","'Sierra'.")
Car1.display()
# Out:
# The Brand of Car is 'TATA' and the Model of Car is 'Sierra'.

# %%
#4. Write a class Employee that stores employee name and salary using init. Create two objects and display their details.

class Employee:
    def __init__(self,employee_name,salary):
        self.employee_name = employee_name
        self.salary = salary
        print("The 'Name' of the Employee is",self.employee_name,"and 'Salary' is",self.salary,".")
        
E1 = Employee("Mr. Anil Kumar Mehta",65000)
E2 = Employee("Miss Megha Shah",85000)
# Out:
# The 'Name' of the Employee is Mr. Anil Kumar Mehta and 'Salary' is 65000 .
# The 'Name' of the Employee is Miss Megha Shah and 'Salary' is 85000 .

# %%
#5. Write a class BankAccount with attributes account_holder and balance. Add a method deposit(amount) that increases the balance.

class BankAccount:
    def __init__(self,account_holder,balance):
        self.account_holder = account_holder
        self.balance = balance
    def deposit(self,amount):
        self.amount = amount
        print("Account Holder :",self.account_holder,", Balance :",self.balance)
        print("Deposit Amount :",self.amount)
        self.balance = self.balance + amount
        print("Increased Balance = Balance + Deposit Amount :",self.balance)

A1 = BankAccount ("'Jiya Gupta'",20000)
A1.deposit(20000)
# Out:
# Account Holder : 'Jiya Gupta' , Balance : 20000
# Deposit Amount : 20000
# Increased Balance = Balance + Deposit Amount : 40000

# %%
#6. Write a class Book with attributes title and author. Create an object and print both attributes.

class Book:
    def __init__(self,title,author):
        self.title = title
        self.author = author
        print("Title of the Book :",self.title)
        print("Author of the Book :",self.author)

B1 = Book("Geetanjali","Rabindranath Tagore")
# Out:
# Title of the Book : Geetanjali
# Author of the Book : Rabindranath Tagore

# %%
#7. Write a class Rectangle that takes length and width in init and has a method area() that returns the area.

class Rectangle:
    def __init__(self,length,width):
        self.length = length
        self.width = width
    def area(self):
        area = self.length * self.width
        return f"Area of Rectangle is : {area}"
a1 = Rectangle(9,3)
print(a1.area())
# Out:
# Area of Rectangle is : 27

# %%
#8. Write a class Mobile with attributes brand and price. If price is not provided, it should default to 10000.

class Mobile:
    def __init__(self,brand,price = 10000):
        self.brand = brand
        self.price = price
        print("Mobile Brand : ",self.brand)
        print("Price :",self.price)
    
        
M1 = Mobile("Samsung",56000)
M2 = Mobile("Realme")
# Out:
# Mobile Brand :  Samsung
# Price : 56000
# Mobile Brand :  Realme
# Price : 10000

# %%
#9. Write a class Calculator with methods add(a, b) and show_result(result) that prints the result.

class Calculator:
    def add(self,a,b):
        self.a = a
        self.b = b
        result = a + b
        return result
    def show_result(self,result):
        print("The addition of",self.a,"and",self.b,"is:",result)
A1 = Calculator()
result = A1.add(48,67)
A1.show_result(result)
# Out:
# The addition of 48 and 67 is: 115

# %%
#10. Write a class Counter that counts how many objects have been created using a class variable.

class Counter:
    count = 0
    
    def __init__(self):
        Counter.count = Counter.count + 1
        
c1 = Counter()
c2 = Counter()
c3 = Counter()

print("The total number of objects :",Counter.count)
# Out:
# The total number of objects : 3

# %%
# Date 13 March

# %%
#1. Create a class Student with attributes name and marks. Use self to assign values and display them.

class Student:
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
        
    def display(self):
        print("Name of Student :",self.name)
        print("Marks :",self.marks)

s1 = Student("Sneha",98)
s1.display()
# Out:
# Name of Student : Sneha
# Marks : 98

# %%
# 2. Create a class Employee that initializes emp_id and salary using __init__.

class Employee:
    def __init__(self,emp_id,salary):
        self.emp_id = emp_id
        self.salary = salary
        print("Employee ID : ",self.emp_id)
        print("Salary : ", self.salary)

E1 = Employee("Ab165133617",56000)
# Out:
# Employee ID :  Ab165133617
# Salary :  56000

# %%
# 3. Create a class Company with:
# class attribute: company_name
# object attribute: employee_name

class Company:
    company_name = "Ashoka PVT LTD"
    
   
    def __init__(self,employee_name):
        self.employee_name = employee_name

    def name(self):
        print("Company Name :",self.company_name)
        print("Employee Name :",self.employee_name)

e1 = Company("Neha Sharma")
e1.name()
print()
e2 = Company("Ravi Verma")
e2.name()
# Out:
# Company Name : Ashoka PVT LTD
# Employee Name : Neha Sharma
#
# Company Name : Ashoka PVT LTD
# Employee Name : Ravi Verma

# %%
# 4. Change class attribute value using class name.

class Product:
    Category = "Electronics"
    
    def __init__(self,product_name,price):
        self.product_name = product_name
        self.price = price
        print("Product :",self.product_name)
        print("Price of product : ",self.price)
        print("Category of product : ",Product.Category)

P1 = Product("Juicer",12000)
Product.Category = "Home Appliances"
print()
P2 = Product("Refridgerator",25000)
# Out:
# Product : Juicer
# Price of product :  12000
# Category of product :  Electronics
#
# Product : Refridgerator
# Price of product :  25000
# Category of product :  Home Appliances

# %%
# 5. Create a static method to check if a number is even.

class check:

    @staticmethod
    def even(a):
        if a % 2 == 0:
            print(a,"is a even number")
        else:
            print(a,"is a odd number")
check.even(34)
# Out:
# 34 is a even number

# %%
# 6. Override __str__() to print object details.

class Student:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"Name : {self.name}\nAge : {self.age}"

s1 = Student("Megha",22)
print(s1)
# Out:
# Name : Megha
# Age : 22

# %%
# 7. Delete an object attribute using del.

class Fruits:
    def __init__(self,fruit_name,quantity):
        self.fruit_name = fruit_name
        self.quantity = quantity
        
       
F1 = Fruits("Apple","2 Dozens")
F2 = Fruits("Mango","1 Dozen")

print("Fruit Name : ",F1.fruit_name)
print("Quantity of Fruits : ",F1.quantity)

del F2.quantity

print()

print("Fruit Name :",F2.fruit_name)
print("Quantity of Fruits :",F2.quantity)
# Out:
# Fruit Name :  Apple
# Quantity of Fruits :  2 Dozens
#
# Fruit Name : Mango
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 20
#      17 print()
#      19 print("Fruit Name :",F2.fruit_name)
# ---> 20 print("Quantity of Fruits :",F2.quantity)
#
# AttributeError: 'Fruits' object has no attribute 'quantity'

# %%
# 8. Delete an object using del.

class Laptop:
    def __init__(self,brand,sell):
        self.brand = brand
        self.sell = sell
        print("Laptop Brand : ",self.brand)
        print("Total Sell of Laptop : ",self.sell)

L1 = Laptop("Dell",35)
L2 = Laptop("Lenovo",40)
L3 = Laptop ("MSI",50)

del L3

print(L1.brand)
print(L2.brand)
print(L3.brand)
# Out:
# Laptop Brand :  Dell
# Total Sell of Laptop :  35
# Laptop Brand :  Lenovo
# Total Sell of Laptop :  40
# Laptop Brand :  MSI
# Total Sell of Laptop :  50
# Dell
# Lenovo
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 18
#      16 print(L1.brand)
#      17 print(L2.brand)
# ---> 18 print(L3.brand)
#
# NameError: name 'L3' is not defined
