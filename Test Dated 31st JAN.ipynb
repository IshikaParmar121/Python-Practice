# %%
# Test Dated 31st Jan , Saturday .

# %%
# print(10 + 5 * 2)

print(10 + 5 * 2)
# Out:
# 20

# %%
print((10 + 5) * 2)
# Out:
# 30

# %%
print(20 - 4 ** 2)
# Out:
# 4

# %%
print(100 // 5 * 2)
# Out:
# 40

# %%
print(18 % 5 + 2)
# Out:
# 5

# %%
print(2 ** 3 ** 2)
# Out:
# 512

# %%
print(4 * 2 ** 3)
# Out:
# 32

# %%
print(16 // 2 ** 2)
# Out:
# 4

# %%
print(9 + 6 * 2 ** 2)
# Out:
# 33

# %%
print(8 - 2 ** 2  * 2)
# Out:
# 0

# %%
print(10 > 5 and 5 > 2)
# Out:
# True

# %%
print(10 > 5 or 5 < 2)
# Out:
# True

# %%
print(not 10 > 5)
# Out:
# False

# %%
print(True or False and True)
# Out:
# True

# %%
print(5 < 10 < 20)
# Out:
# True

# %%
x = 5; x+=3 * 2 
print(x)
# Out:
# 11

# %%
x = 10; x *= 2 + 3
print(x)
# Out:
# 50

# %%
x = 5; x = x == 5
print(x)
# Out:
# True

# %%
x = 2; x **= 2 + 1
print(x)
# Out:
# 8

# %%
x = 1; x += x == 1
print(x)
# Out:
# 2

# %%
print(5 and 0 or 8)
# Out:
# 8

# %%
print(0 or 5 and 8)
# Out:
# 8

# %%
print(True == False or True)
# Out:
# True

# %%
print(False == False and True)
# Out:
# True

# %%
print( not True == False)
# Out:
# True

# %%
## WAP to check  if a given character is present in a string  entered by user
# Input String = "hello", Character = "e"
# output: "e" is present in the string.

s = "hello"
c = "e"
if c in s:
    print(c,"is present in the string")
# Out:
# e is present in the string

# %%
# WAP to check if a given number is in a predefined list of prime numbers.
# Input: Number = 7, List[ 2,3,5,7,11]
# Output: 7 is a prime number
number = 7
l = [ 2,3,5,7,11]
print(number,"is a prime number")
# Out:
# 7 is a prime number

# %%
# WAP to check if a user's chosen username is already in a list of existing usernames.
# Input: Username = "john123" , Existing = [ "alice","bob","john123"]
# Output: Username already taken

Username = "john123"
Existing = ["alice","bob","john123"]
if Username in Existing:
    print("Usename already taken")
# Out:
# Usename already taken

# %%
# WAP to check if a word is part of a given sentence (input both word and sentence).
# Input: Word = "sun". Sentence= "The sun rises in the east".
# Outout: "sun is present in the sentence.
Word = "sun"
Sentence= "The sun rises in the east"
if Word in Sentence:
    print(Word,"is present in the sentence")
# Out:
# sun is present in the sentence

# %%
# WAP to check if an item is not present in a shopping cart list and add it if it's missing.
# Input: Item = "milk",Cart = ["bread","eggs"]
# Output: milk was not in the cart. Added now.
Item = "milk"
Cart = ["bread","eggs"]
if Item not in Cart:
    print(Item,"was not in the cart, Added now.")
# Out:
# milk was not in the cart, Added now.

# %%
# WAPP to check if two variables refer to the same object in memory.
# Input: a = [1,2], b = a
# Output: a and b refer to the same object
a = [1,2]
b = a
if a is b:
    print("a and b refer to the same object")
# Out:
# a and b refer to the same object

# %%
# WAP to input two lists and check if they are the same object or different objects.
# Input list1 = [1,2,3], list2 = [1,2,3]
# Output: list1 and list2 do not refer to the same object.
list1 = [1,2,3]
list2 = [1,2,3]
if list1 is not list2:
    print("list1 and list2 do not refer to the same object")
# Out:
# list1 and list2 do not refer to the same object

# %%
# WAP to check if a variable is "None" and print a message if it is.
# Input: var = None
# Output: The variable is None
var = None
if var is None:
    print("The variable is None")
# Out:
# The variable is None

# %%
# WAP to check if a user's input is not "None" and proceed only if it is not. 

# Input: var = "Hello"
# Output: "The variable is not None.
var = "Hello"
if var is not None:
    print("The variable is not None")
# Out:
# The variable is not None

# %%
# WAP to compare two strings and check if they are the same object or just equal in value.
# Input str1 = "apple",str2 = ["a","p","p","l","e"]
# output: str2 and str1 have the same value but are not the same object.
str1 = "apple"
str2 = "".join(["a","p","p","l","e"])
if str1 == str2:
    print("str2 and str1 have the same value but are not the same object")
# Out:
# str2 and str1 have the same value but are not the same object
