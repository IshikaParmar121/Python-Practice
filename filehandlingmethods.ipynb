# %%
# os.walk()
# Definition ==> Used to traverse all directories and files inside a folder.
import os

for current_folder,dirs,files in os.walk(""):
    print("Folder:", current_folder)
    print("Subfolders:",dirs)
    print("Files:",files)

# %%
import os

for current_folder,dirs,files in os.walk("New folder"):
    for file in files:
        print(file,end = " ")
# Out:
# coma.py first.py Type.py

# %%
import os

for current_folder,dirs,files in os.walk("Downloads"):
    for Subfolders in dirs:
        print(dirs,end = "")
# Out:
# ['Adobe After Effects Auto-Save', 'Adobe Premiere Pro 2024 v24.6.1 (x64)', 'After.Effects.2025', 'Audio-Win10_Win11-6.0.9360.1', 'Compressed', 'Convergence,Emilys_Candy,Lily_Script_One,Montserrat,Open_Sans', 'Deep_Glow_2_v1.0.2', 'Emilys_Candy,Lily_Script_One,Montserrat,Open_Sans', 'Emilys_Candy,Montserrat,Open_Sans', 'FXConsole_1.0.5_Installer_Win_2022.1', 'GoodbyeGreenscreen-v2.1.1-Win', 'hidayatullah', 'Montserrat', 'New folder', 'New folder (2)', 'Open_Sans', 'Premiere.Pro.2025', 'Programs', 'ramadhan_mubarok', 'V2_1.9.1051.3012', 'Video', 'WhatsApp Unknown 2024-10-13 at 7.54.29 PM']['Adobe After Effects Auto-Save', 'Adobe Premiere Pro 2024 v24.6.1 (x64)', 'After.Effects.2025', 'Audio-Win10_Win11-6.0.9360.1', 'Compressed', 'Convergence,Emilys_Candy,Lily_Script_One,Montserrat,Open_Sans', 'Deep_Glow_2_v1.0.2', 'Emilys_Candy,Lily_Script_One,Montserrat,Open_Sans', 'Emilys_Candy,Montserrat,Open_Sans', 'FXConsole_1.0.5_Installer_Win_2022.1', 'GoodbyeGreenscreen-v2.1.1-Win', 'hidayatull
# ...

# %%
# os.rename()
# Definition ==> Used to rename files or folders.

import os
os.rename("new.txt","old.txt")

# %%
import os
os.rename("Untitled.ipynb","strdiclist.ipynb")
